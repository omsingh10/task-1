# %%
# %pip install pandas
import pandas as pd
# Out:
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.0 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.0 MB 394.4 kB/s eta 0:00:27
#    - -------------------------------------- 0.5/11.0 MB 394.4 kB/s eta 0:00:27
#    - -------------------------------------- 0.5/11.0 MB 394.4 kB/s eta 0:00:27
#    -- ------------------------------------- 0.8/11.0 MB 416.3 kB/s eta 0:00:25
# ...

# %%
try:
    import pandas
    print("pandas is installed")
except ImportError:
    print("pandas is NOT installed")
# Out:
# pandas is installed
